# %%
from pinecone.grpc import PineconeGRPC as Pinecone

pc = Pinecone()
index_name = "branded-food-data"
index = pc.Index(index_name)

# %%
def similarity_search(query, index, pc, top_k=10):
    query_embedding = pc.inference.embed(
        model="multilingual-e5-large",
        inputs=[query],
        parameters={"input_type": "query"}
    )

    if query_embedding and 'values' in query_embedding[0]:
        results = index.query(
            vector=query_embedding[0]['values'],
            top_k=top_k,
            include_metadata=True
        )
        return results['matches'] if results['matches'] else []
    else:
        return []

# %%
def format_retrieved_food_data(raw_retrieved_food_data):
    formatted_retrieved_food_data = ""
    
    for idx, match in enumerate(raw_retrieved_food_data, start=1):
        metadata = match['metadata']
        food_name = metadata.get("FOOD_NAME", "Unknown Food Name")
        
        formatted_retrieved_food_data += f"{idx}. {food_name}\nFood Details:\n"
        for key, value in metadata.items():
            if key != "FOOD_NAME":
                formatted_retrieved_food_data += f"{key}: {value}\n"
        formatted_retrieved_food_data += "\n"
    
    return formatted_retrieved_food_data

# %%
query = "oreo cookies"
raw_retrieved_food_data = similarity_search(query, index, pc)
formatted_retrieved_food_data = format_retrieved_food_data(raw_retrieved_food_data)

print(formatted_retrieved_food_data)
# Out:
# 1. OREO COOKIES
# Food Details:
# CARBOHYDRATE, BY DIFFERENCE (G): 73.0
# FOOD_ID: 07622300688455
# FOOD_RECORD_ID: 770088
# FIBER, TOTAL DIETARY (G): 2.5
# PROTEIN (G): 5.0
# TOTAL SUGARS (G): 38.0
# TOTAL LIPID (FAT) (G): 20.0
# FATTY ACIDS, TOTAL SATURATED (G): 9.8
# FOOD_INGREDIENTS: INGREDIENTS: WHEAT FLOUR, SUGAR, VEGETABLE OILS (PALM, PALM KERNEL), FAT REDUCED COCOA POWDER 4,6%, WHEAT STARCH, GLUCOSE-FRUCTOSE SYRUP, RAISING AGENTS (POTASSIUM HYDROGEN CARBONATE, AMMONIUM HYDROGEN CARBONATE, SODIUM HYDROGEN CARBONATE), SALT, EMULSIFIERS (SOYA LECITHIN, SUNFLOWER LECITHIN), FLAVOURING. MAY CONTAIN MILK.
# SODIUM, NA (MG): 400.0
# FOOD_SERVING_SIZE: 100.0 G
#
# 2. OREO COOKIE PIECES
# Food Details:
# SODIUM, NA (MG): 550.0
# CARBOHYDRATE, BY DIFFERENCE (G): 71.43
# FOOD_ID: 018894250975
# FOOD_RECORD_ID: 2105489
# FIBER, TOTAL DIETARY (G): 0.0
# PROTEIN (G): 7.14
# TOTAL SUGARS (G): 42.86
# TOTAL LIPID (FAT) (G): 21.43
# FOOD_INGREDIENTS: UNBLEACHED ENRICHED FLOUR,(WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, (VIT. B1) RIBOFLAVIN, (VIT. B2), FOLIC ACID), SUGAR, PALM &/OR CANOLA OIL, COCOA (PROCESSED WITH ALKALI), HIGH FRUCTOSE CORN SYRUP, LEAVENING (BAKING SODA &/OR CALCIUM PHOSPHATE), SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR.
# ENERGY (KCAL): 500.0
# FOOD_SERVING_SIZE: 14.0 G
#
# 3. OREO COOKIE PIECES
# Food Details:
# FOOD_ID: 604485906514
# FOOD_RECORD_ID: 2127841
# VITAMIN D (D2 + D3), INTERNATIONAL UNITS (IU): 0.0
# TOTAL SUGARS (G): 38.89
# TOTAL LIPID (FAT) (G): 22.22
# FATTY ACIDS, TOTAL TRANS (G): 0.0
# FATTY ACIDS, TOTAL SATURATED (G): 5.56
# POTASSIUM, K (MG): 0.0
# ENERGY (KCAL): 500.0
# FOOD_SERVING_SIZE: 18.0 G
# CALCIUM, CA (MG): 0.0
# CARBOHYDRATE, BY DIFFERENCE (G): 77.78
# FIBER, TOTAL DIETARY (G): 5.6
# PROTEIN (G): 5.56
# IRON, FE (MG): 0.0
# CHOLESTEROL (MG): 0.0
# FOOD_INGREDIENTS: UNBLEACHED ENRICHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, (VIT. B1) RIBOFLAVIN, (VIT. B2), FOLIC ACID), SUGAR, PALM &/OR CANOLA OIL, COCOA (PROCESSED WITH ALKALI), HIGH FRUCTOSE CORN SYRUP, LEAVENING (BAKING SODA &/OR CALCIUM PHOSPHATE), SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR.
# SUGARS, ADDED (G): 38.9
# SODIUM, NA (MG): 483.0
#
# 4. OREO COOKIES VANILLA
# Food Details:
# FOOD_ID: 07622210317667
# FOOD_RECORD_ID: 770414
# FIBER, TOTAL DIETARY (G): 2.5
# PROTEIN (G): 5.0
# TOTAL SUGARS (G): 38.0
# TOTAL LIPID (FAT) (G): 20.0
# FATTY ACIDS, TOTAL SATURATED (G): 9.8
# FOOD_INGREDIENTS: INGREDIENTS: WHEAT FLOUR, SUGAR, VEGETABLE OIL (PALM), FAT REDUCED COCOA POWDER 4,6%, WHEAT STARCH, GLUCOSE-FRUCTOSE SYRUP, SALT, RAISING AGENTS (POTASSIUM HYDROGEN CARBONATE, SODIUM HYDROGEN CARBONATE, AMMONIUM HYDROGEN CARBONATE), EMULSIFIERS (SOYA LECITHIN, SUNFLOWER LECITHIN), FLAVOURING (VANILLIN). MAY CONTAIN MILK.
# FOOD_SERVING_SIZE: 100.0 G
#
# 5. GOURMET EDIBLE COOKIE DOUGH, OREO
# Food Details:
# FOOD_ID: 850947006135
# FOOD_RECORD_ID: 1933538
# VITAMIN C, TOTAL ASCORBIC ACID (MG): 0.0
# TOTAL SUGARS (G): 35.09
# TOTAL LIPID (FAT) (G): 12.28
# FATTY ACIDS, TOTAL TRANS (G): 0.0
# FATTY ACIDS, TOTAL SATURATED (G): 7.02
# ENERGY (KCAL): 368.0
# FOOD_SERVING_SIZE: 57.0 G
# CALCIUM, CA (MG): 35.0
# CARBOHYDRATE, BY DIFFERENCE (G): 63.16
# FIBER, TOTAL DIETARY (G): 0.0
# PROTEIN (G): 3.51
# IRON, FE (MG): 1.89
# CHOLESTEROL (MG): 26.0
# VITAMIN A, IU (IU): 351.0
# FOOD_INGREDIENTS: WHEAT FLOUR, BROWN SUGAR, BUTTER (PASTEURIZED CREAM, NATURAL FLAVOR), WATER, SUGAR, OREO COOKIES (UNBLEACHED ENRICHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE {VITAMIN B1}, RIBOFLAVIN {VITAMIN B2}, FOLIC ACID), SUGAR, PALM AND/OR CANOLA OIL, COCOA (PROCESSED WITH ALKALI), HIGH FRUCTOSE CORN SYRUP, LEAVENING (BAKING SODA AND/OR CALCIUM PHOSPHATE) SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR), SEA SALT, NATURAL FLAVOR.
# SODIUM, NA (MG): 386.0
#
# 6. OREO FROSTED COOKIES, OREO
# Food Details:
# FOOD_ID: 770981301990
# FOOD_RECORD_ID: 2670912
# TOTAL SUGARS (G): 42.11
# TOTAL LIPID (FAT) (G): 15.79
# FATTY ACIDS, TOTAL TRANS (G): 0.0
# FATTY ACIDS, TOTAL SATURATED (G): 3.95
# POTASSIUM, K (MG): 132.0
# VITAMIN D (D2 + D3) (UG): 3.0
# ENERGY (KCAL): 421.0
# FOOD_SERVING_SIZE: 38.0 GRM
# CALCIUM, CA (MG): 26.0
# CARBOHYDRATE, BY DIFFERENCE (G): 63.16
# FIBER, TOTAL DIETARY (G): 2.6
# PROTEIN (G): 2.63
# IRON, FE (MG): 2.89
# CHOLESTEROL (MG): 13.0
# FOOD_INGREDIENTS: BLEACHED ENRICHED WHEAT FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, RIBOFLAVIN, FOLIC ACID), ICING SUGAR (SUGAR, CORNSTARCH), MARGARINE (SOYBEAN OIL, PALM OIL, WATER, SALT, WHEY [MILK], SOYBEAN LECITHIN, MONOGLYCERIDES, NATURAL FLAVOR, VITAMIN A PALMITATE, VITAMIN D3), SUGAR, WATER, EGGS, COCOA POWDER (PROCESSED WITH ALKALI), INVERT SUGAR, FRUCTOSE, OREO COOKIE CRUMB (ENRICHED WHEAT FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, RIBOFLAVIN, FOLIC ACID], SUGAR, CANOLA OIL, COCOA POWDER [PROCESSED WITH ALKALI], HIGH FRUCTOSE CORN SYRUP, SALT, SOYBEAN LECITHIN [EMULSIFIER], LEAVENING [SODIUM BICARBONATE, AMMONIUM BICARBONATE], UNSWEETENED CHOCOLATE, ARTIFICIAL FLAVOR), MODIFIED CORNSTARCH, NONFAT DRY MILK, LEAVENING BLEND (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, ENRICHED WHEAT FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, RIBOFLAVIN, FOLIC ACID], MONOCALCIUM PHOSPHATE, CALCIUM SULFATE), SALT, POLYSORBATE 60, ARTIFICIAL FLAVOR.
# SUGARS, ADDED (G): 42.1
# SODIUM, NA (MG): 368.0
#
# 7. OREO PIECES SUGAR CONES COOKIE, OREO PIECES
# Food Details:
# FOOD_ID: 072092121215
# FOOD_RECORD_ID: 2215818
# VITAMIN D (D2 + D3), INTERNATIONAL UNITS (IU): 0.0
# TOTAL SUGARS (G): 33.33
# TOTAL LIPID (FAT) (G): 3.33
# FATTY ACIDS, TOTAL TRANS (G): 0.0
# FATTY ACIDS, TOTAL SATURATED (G): 0.0
# POTASSIUM, K (MG): 333.0
# ENERGY (KCAL): 400.0
# FOOD_SERVING_SIZE: 15.0 G
# CALCIUM, CA (MG): 67.0
# CARBOHYDRATE, BY DIFFERENCE (G): 86.67
# FIBER, TOTAL DIETARY (G): 6.7
# PROTEIN (G): 6.67
# IRON, FE (MG): 4.0
# CHOLESTEROL (MG): 0.0
# FOOD_INGREDIENTS: BLEACHED ENRICHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, RIBOFLAVIN, FOLIC ACID), BROWN SUGAR, OREO BASECAKE CRUMB (ENRICHED FLOUR (WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE, RIBOFLAVIN, FOLIC ACID), SUGAR, CANOLA OIL, COCOA (PROCESSED WITH ALKALI), INVERT SUGAR, LEAVENING (BAKING SODA AND/OR CALCIUM PHOSPHATE), SALT, SOY LECITHIN, CHOCOLATE, NATURAL FLAVOR), COCOA (PROCESSED WITH ALKALI), CONTAINS LESS THAN 2% OF: SOY LECITHIN, VEGETABLE OIL SHORTENING (CANOLA OIL AND/OR MODIFIED PALM OIL AND/OR SOYBEAN OIL), ARTIFICIAL COLOR (RED #40, BLUE #1, YELLOW #5 AND RED #3), SALT, NATURAL FLAVOR, OAT FIBER.
# SUGARS, ADDED (G): 26.7
# SODIUM, NA (MG): 567.0
#
# 8. OREOS CHOCOLATE COVERED COOKIE
# Food Details:
# FOOD_ID: 086374008859
# FOOD_RECORD_ID: 2445050
# VITAMIN D (D2 + D3), INTERNATIONAL UNITS (IU): 0.0
# TOTAL SUGARS (G): 50.0
# TOTAL LIPID (FAT) (G): 30.0
# FATTY ACIDS, TOTAL TRANS (G): 0.0
# FATTY ACIDS, TOTAL SATURATED (G): 16.67
# POTASSIUM, K (MG): 260.0
# ENERGY (KCAL): 500.0
# FOOD_SERVING_SIZE: 30.0 G
# CALCIUM, CA (MG): 163.0
# CARBOHYDRATE, BY DIFFERENCE (G): 60.0
# FIBER, TOTAL DIETARY (G): 0.0
# PROTEIN (G): 6.67
# IRON, FE (MG): 3.33
# CHOLESTEROL (MG): 17.0
# FOOD_INGREDIENTS: MILK CHOCOLATE (SUGAR, MILK, COCOA BUTTER, CHOCOLATE LIQUOR, SOY LECITHIN [AN EMULSIFIER] AND VANILLIN [AN ARTIFICIAL FLAVOR]), OREO COOKIES (UNBLEACHED ENRICHED FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE {VITAMIN B1}, RIBOFLAVIN {VITAMIN B2}, FOLIC ACID], SUGAR, PALM AND/OR CANOLA OIL, COCOA [PROCESSED WITH ALKALI], HIGH FRUCTOSE CORN SYRUP, LEAVENING [BAKING SODA AND/OR CALCIUM PHOSPHATE], SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR), DECORETTES (SUGAR, UNSWEETENED CHOCOLATE, COCOA [PROCESSED WITH POTASSIUM CARBONATE], VEGETABLE OIL [PALM, PALM KERNEL], CORNSTARCH, LECITHIN [SOY, SOYA], CONFECTIONER'S GLAZE, CORN SYRUP, DEXTRIN, RED 3, RED 40 LAKE, YELLOW 6 LAKE, NATURAL AND ARTIFICIAL FLAVOR, CARNAUBA WAX, VANILLIN [AN ARTIFICIAL FLAVOR] AND SALT).
# SUGARS, ADDED (G): 30.0
# SODIUM, NA (MG): 167.0
#
# 9. MILK CHOCOLATE OREO COOKIES ENROBED IN MILK CHOCOLATE & TOPPED WITH CHOCOLATEY DRIZZLE, MILK CHOCOLATE
# Food Details:
# FOOD_ID: 857484001838
# FOOD_RECORD_ID: 2587582
# TOTAL SUGARS (G): 54.17
# TOTAL LIPID (FAT) (G): 25.0
# FATTY ACIDS, TOTAL TRANS (G): 0.0
# FATTY ACIDS, TOTAL SATURATED (G): 12.5
# POTASSIUM, K (MG): 208.0
# VITAMIN D (D2 + D3) (UG): 0.0
# ENERGY (KCAL): 500.0
# FOOD_SERVING_SIZE: 24.0 GRM
# CALCIUM, CA (MG): 104.0
# CARBOHYDRATE, BY DIFFERENCE (G): 70.83
# FIBER, TOTAL DIETARY (G): 0.0
# PROTEIN (G): 4.17
# IRON, FE (MG): 3.71
# CHOLESTEROL (MG): 0.0
# FOOD_INGREDIENTS: SANDWICH COOKIE (UNBLEACHED ENRICHED FLOUR [WHEAT FLOUR, NIACIN, REDUCED IRON, THIAMINE MONONITRATE {VITAMIN B1}, RIBOFLAVIN {VITAMIN B2}, FOLIC ACID], SUGAR, PALM AND/OR CANOLA OIL, COCOA [PROCESSED WITH ALKALI], HIGH FRUCTOSE CORN SYRUP, LEAVENING [BAKING SODA AND/OR CALCIUM PHOSPHATE], SALT, SOY LECITHIN, CHOCOLATE, ARTIFICIAL FLAVOR), MILK CHOCOLATE (SUGAR, COCOA BUTTER, MILK, CHOCOLATE LIQUOR, NONFAT MILK, SOY LECITHIN [AN EMULSIFIER], VANILLA), RED, GREEN & WHITE DRIZZLE (SUGAR, VEGETABLE OIL [PALM KERNEL OIL AND HYDROGENATED PALM KERNEL OIL], WHOLE MILK SOLIDS, WHEY POWDER NONFAT DRY MILK SOLIDS, ARTIFICIAL COLORS [RED #40, YELLOW #5, BLUE #1], SOY LECITHIN [AN EMULSIFIER], SALT, ARTIFICIAL FLAVOR).
# SUGARS, ADDED (G): 50.0
# SODIUM, NA (MG): 271.0
#
# 10. OREO COOKIES MILK CHOCOLATE COVERED
# Food Details:
# CARBOHYDRATE, BY DIFFERENCE (G): 67.0
# FOOD_ID: 07622300691301
# FOOD_RECORD_ID: 770608
# FIBER, TOTAL DIETARY (G): 2.3
# PROTEIN (G): 4.8
# TOTAL SUGARS (G): 47.0
# TOTAL LIPID (FAT) (G): 26.0
# FATTY ACIDS, TOTAL SATURATED (G): 14.5
# FOOD_INGREDIENTS: INGREDIENTS: SUGAR, WHEAT FLOUR, VEGETABLE OILS (PALM, PALM KERNEL), COCOA BUTTER, COCOA MASS, SKIMMED MILK POWDER, FAT REDUCED COCOA POWDER 2.5%, WHEAT STARCH, LACTOSE (FROM MILK), ANHYDROUS MILK FAT, GLUCOSE-FRUCTOSE SYRUP, RAISING AGENTS (POTASSIUM HYDROGEN CARBONATE, AMMONIUM HYDROGEN CARBONATE, SODIUM HYDROGEN CARBONATE), EMULSIFIERS (SOYA LECITHIN, SUNFLOWER LECITHIN), SALT, FLAVOURING.
# SODIUM, NA (MG): 230.0
# FOOD_SERVING_SIZE: 100.0 G
